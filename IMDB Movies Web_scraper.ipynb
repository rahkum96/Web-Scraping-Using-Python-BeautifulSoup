# %% [markdown]
# # Web Scraper
# ### IMDB Movie Rating
# url='https://www.imdb.com/chart/top/'

# %%
import requests # for url
from bs4 import BeautifulSoup # for html file

# %%
url= requests.get('https://www.imdb.com/chart/top/')
# Lets check the the url is valid or not 
url.raise_for_status() # Here it doent throw an error it means the url link is valid

# %%
# Now we have to get html written code here by using parser
soup= BeautifulSoup(url.text,'html.parser')

# %%
# Now we have find the tag in html file for 250 movies 
movies= soup.find('tbody', class_= 'lister-list') 
# find will try to match the first tag who has 'tbody' and class with 'lister-list'
#Here class is different meaning in python, so we will use class with underscore  "class_"

# from tbody we have find all 'tr' tags which is movie list of 250 movies
movies=movies.find_all('tr')

# %%
# I will for loop for extracting 250 movies name
movie_details=[]
for movie in movies:
    name= movie.find('td', class_="titleColumn").a.text 
# We are fetching the name of movies by first entring into the 'td' tag then 'a'tag then fetching the text of 'a' tag
    name1= movie.find('td', class_="titleColumn").text # Here we are getting spaces and not formated 
    name2= movie.find('td', class_="titleColumn").get_text(strip= True) # Here we remove the all the spaces 
    
    #rank
    rank= movie.find('td', class_="titleColumn").get_text(strip= True).split('.')[0] 
    # Here i am split so, it will split into two string and indexing 1st element 
    
    #year
    year= movie.find('td', class_="titleColumn").span.text 
    # first entering into thr 'td' tag then 'span'tag from there fetching text
    year1= year.strip('()') # Here i am stripping '()'
    
    # Rating, 
    rating=movie.find('td', class_= 'ratingColumn imdbRating').strong.text
#     
#     print(name)
#     print(name1)
#     print(name2)
#     print(rank)
#     print(year)
#     print(year1)
#     print(rating)
    
    print(rank,name,year1,rating)
    movie_details.append([rank,name,year1,rating])
    #break   # i want to extract only 1 movie name, if we remove break it will print all 250 movies name
# Out:
# 1 The Shawshank Redemption 1994 9.2
# 2 The Godfather 1972 9.1
# 3 The Godfather: Part II 1974 9.0
# 4 The Dark Knight 2008 9.0
# 5 12 Angry Men 1957 8.9
# 6 Schindler's List 1993 8.9
# 7 The Lord of the Rings: The Return of the King 2003 8.9
# 8 Pulp Fiction 1994 8.8
# 9 Spider-Man: No Way Home 2021 8.8
# 10 Il buono, il brutto, il cattivo 1966 8.8
# 11 The Lord of the Rings: The Fellowship of the Ring 2001 8.8
# 12 Fight Club 1999 8.7
# 13 Forrest Gump 1994 8.7
# 14 Inception 2010 8.7
# 15 The Lord of the Rings: The Two Towers 2002 8.7
# 16 Star Wars: Episode V - The Empire Strikes Back 1980 8.7
# 17 CM101MMXI Fundamentals 2013 8.7
# 18 The Matrix 1999 8.6
# 19 Goodfellas 1990 8.6
# 20 One Flew Over the Cuckoo's Nest 1975 8.6
# 21 Shichinin no samurai 1954 8.6
# 22 Se7en 1995 8.6
# 23 The Silence of the Lambs 1991 8.6
# 24 Cidade de Deus 2002 8.6
# 25 La vita è bella 1997 8.6
# 26 It's a Wonderful Life 1946 8.6
# 27 Saving Private Ryan 1998 8.6
# 28 Star Wars 1977 8.6
# 29 Interstellar 2014 8.5
# 30 Sen to Chihiro no kamikakushi 2001 8.5
# 31 The Green Mile 1999 8.5
# 32 Gisaengchung 2019 8.5
# 33 Léon 1994 8.5
# 34 Seppuku 1962 8.5
# 35 The Pianist 2002 8.5
# 199 Mr. Smith Goes to Washington 1939 8.1
# 200 In the Name of the Father 1993 8.1
# 201 Barry Lyndon 1975 8.1
# 202 Room 2015 8.1
# 203 Gone Girl 2014 8.1
# 204 Hacksaw Ridge 2016 8.1
# 205 La passion de Jeanne d'Arc 1928 8.1
# 206 Andhadhun 2018 8.1
# 207 Ford v Ferrari 2019 8.1
# 208 12 Years a Slave 2013 8.1
# 209 To Be or Not to Be 1942 8.1
# 210 The Big Lebowski 1998 8.1
# 211 Dead Poets Society 1989 8.1
# 212 How to Train Your Dragon 2010 8.1
# 213 Höstsonaten 1978 8.1
# 214 Mad Max: Fury Road 2015 8.1
# 215 Ben-Hur 1959 8.1
# 216 Harry Potter and the Deathly Hallows: Part 2 2011 8.1
# 217 Million Dollar Baby 2004 8.1
# 218 Ah-ga-ssi 2016 8.1
# 219 Le salaire de la peur 1953 8.1
# 220 Stand by Me 1986 8.1
# 221 Network 1976 8.1
# 222 Gangs of Wasseypur 2012 8.1
# 223 Logan 2017 8.1
# 224 Cool Hand Luke 1967 8.0
# 225 Hachi: A Dog's Tale 2009 8.0
# 226 La haine 1995 8.0
# 227 Koe no katachi 2016 8.0
# 228 Les quatre cents coups 1959 8.0
# 229 Platoon 1986 8.0
# 230 Spotlight 2015 8.0
# 231 Monsters, Inc. 2001 8.0
# 232 Rebecca 1940 8.0
# 233 Life of Brian 1979 8.0
# 234 Eskiya 1996 8.0
# 235 Hotel Rwanda 2004 8.0
# 236 Fa Yeung Nin Wah 2000 8.0
# 237 Rush 2013 8.0
# 238 Into the Wild 2007 8.0
# 239 Amores perros 2000 8.0
# 240 Rocky 1976 8.0
# 241 Kaze no tani no Naushika 1984 8.0
# 242 It Happened One Night 1934 8.0
# 243 Andrei Rublev 1966 8.0
# 244 Before Sunset 2004 8.0
# 245 Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni 1997 8.0
# 246 Fanny och Alexander 1982 8.0
# 247 La battaglia di Algeri 1966 8.0
# 248 Le notti di Cabiria 1957 8.0
# 249 The Princess Bride 1987 8.0
# 250 Paris, Texas 1984 8.0

# %%
movie_details[1]
# Out:
# ['2', 'The Godfather', '1972', '9.1']

# %% [markdown]
# ## Let's make DataFrame

# %%
import pandas as pd
df= pd.DataFrame(movie_details, columns=['Rating','Movie_name','Year_realse','IMDB_rating'])

# %%
df.head()
# Out:
#   Rating                Movie_name Year_realse IMDB_rating
# 0      1  The Shawshank Redemption        1994         9.2
# 1      2             The Godfather        1972         9.1
# 2      3    The Godfather: Part II        1974         9.0
# 3      4           The Dark Knight        2008         9.0
# 4      5              12 Angry Men        1957         8.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rating       250 non-null    object
#  1   Movie_name   250 non-null    object
#  2   Year_realse  250 non-null    object
#  3   IMDB_rating  250 non-null    object
# dtypes: object(4)
# memory usage: 7.9+ KB

# %%
df['Rating']=df['Rating'].astype('int')
df['IMDB_rating']=df['IMDB_rating'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rating       250 non-null    int32
#  1   Movie_name   250 non-null    object
#  2   Year_realse  250 non-null    object
#  3   IMDB_rating  250 non-null    float64
# dtypes: float64(1), int32(1), object(2)
# memory usage: 7.0+ KB

# %% [markdown]
# ### Moving data to excel

# %%
df.to_excel(r'Top Movies.xlsx',index=False)
